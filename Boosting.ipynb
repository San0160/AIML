# %%
# Boosting 
# The code till train_test_split is taken from previous projects (skip to title)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %%
# These steps are common 4 all Supervised machine learning algorithems :)

# Read Data
# perform EDA
# Preprocessing

# Identify X and y
# Split the data in train and test

# Build the model                                (This is where we generally loop if results are not satisfying)
# Make Predection on train and test data

# Evaluate the Model

# %%
Db = pd.read_csv("C:\\Users\\Sandeep\\OneDrive\\Desktop\\Classes and Files\\diabetes.csv")

# %%
Db
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
Db.shape
# Out:
# (768, 9)

# %%
Db.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
Db.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
Db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
Db.boxplot(column='Glucose', by ='Outcome', figsize=(5,6))
# Out:
# <Axes: title={'center': 'Glucose'}, xlabel='Outcome'>

# %%
for col in Db.columns: Db.boxplot(column=col, by='Outcome', figsize=(5,6))

# %%
sns.relplot(data=Db, x="Glucose", y="Insulin", hue="Outcome")

# %%
Db.hist(column = "Glucose" , bins = 25 , grid = 'false', figsize = (10,6), color = 'green' , zorder = 2, rwidth = 0.9)
# Out:
# array([[<Axes: title={'center': 'Glucose'}>]], dtype=object)

# %%
# I used 3 types of graph here, generally 1 is enough and there are standards to which we can choose the graph based on data that is present i.e. Numericall or categorical

# %%
Db.hist(column = "Insulin" , bins = 25 , grid = 'false', figsize = (10,6), color = 'green' , zorder = 2, rwidth = 0.9)
# Out:
# array([[<Axes: title={'center': 'Insulin'}>]], dtype=object)

# %%
Db.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
Db.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
Db.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
X = Db[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]
y = Db[['Outcome']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.7, random_state = 123)

# %%
print("Shapes")
print("X_train",X_train.shape)
print("y_train",y_train.shape)
print("X_test",X_test.shape)
print("y_test",y_test.shape)
# Out:
# Shapes
# X_train (537, 8)
# y_train (537, 1)
# X_test (231, 8)
# y_test (231, 1)

# %% [markdown]
# # Boosting
#
# ## 1) XgBoost

# %%
from xgboost import XGBClassifier

# %%
xgb =XGBClassifier()                             # for Parameters we got same stuff as RF i.e. N_estimator, Depth , Criteria
xgb.fit(X_train, y_train)                        # We also have learning rate
                                                 # By default the depth = 6
                                                 #                N_estimator = 100
                                                 #                learning rate = 0.3
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
pred_train = xgb.predict(X_train)

print("Confusion matrix")
print(confusion_matrix(pred_train, y_train))
print(" ")
print("Classification Report")
print(classification_report(pred_train, y_train))
# Out:
# Confusion matrix
# [[357   0]
#  [  0 180]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       357
#            1       1.00      1.00      1.00       180
#
#     accuracy                           1.00       537
#    macro avg       1.00      1.00      1.00       537
# weighted avg       1.00      1.00      1.00       537

# %%
xgbt =XGBClassifier() 
xgbt.fit(X_test, y_test)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
pred_test = xgb.predict(X_test)

print("Confusion matrix")
print(confusion_matrix(y_test, pred_test))
print(" ")
print("Classification Report")
print(classification_report(y_test, pred_test))
# Out:
# Confusion matrix
# [[114  29]
#  [ 26  62]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.81       143
#            1       0.68      0.70      0.69        88
#
#     accuracy                           0.76       231
#    macro avg       0.75      0.75      0.75       231
# weighted avg       0.76      0.76      0.76       231

# %%
xgb1 =XGBClassifier(max_depth = 4)                # Since the model is overfitted lets reduce the max depth to make the model simpler
xgb1.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
pred_train1 = xgb1.predict(X_train)

print("Confusion matrix")
print(confusion_matrix(y_train, pred_train1))
print(" ")
print("Classification Report")
print(classification_report(y_train, pred_train1))
# Out:
# Confusion matrix
# [[357   0]
#  [  0 180]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       357
#            1       1.00      1.00      1.00       180
#
#     accuracy                           1.00       537
#    macro avg       1.00      1.00      1.00       537
# weighted avg       1.00      1.00      1.00       537

# %%
xgb_t =XGBClassifier(max_depth = 4)
xgb_t.fit(X_test, y_test)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
pred_test_1 = xgb_t.predict(X_test)

print("Confusion matrix")
print(confusion_matrix(y_test, pred_test_1))
print(" ")
print("Classification Report")
print(classification_report(y_test, pred_test_1))
# Out:
# Confusion matrix
# [[143   0]
#  [  0  88]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       143
#            1       1.00      1.00      1.00        88
#
#     accuracy                           1.00       231
#    macro avg       1.00      1.00      1.00       231
# weighted avg       1.00      1.00      1.00       231

# %%
xgb2 =XGBClassifier(max_depth = 5, criterion = 'entropy', n_estimators = 200) 
xgb2.fit(X_train, y_train)
# Out:
# C:\Users\Sandeep\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:160: UserWarning: [23:08:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0cec3277c4d9d0165-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "criterion" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, criterion='entropy', device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
# ...

# %%
pred_train2 = xgb2.predict(X_train)

print("Confusion matrix")
print(confusion_matrix(y_train, pred_train2))
print(" ")
print("Classification Report")
print(classification_report(y_train, pred_train2))
# Out:
# Confusion matrix
# [[357   0]
#  [  0 180]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       357
#            1       1.00      1.00      1.00       180
#
#     accuracy                           1.00       537
#    macro avg       1.00      1.00      1.00       537
# weighted avg       1.00      1.00      1.00       537

# %%
xgb_2 =XGBClassifier(max_depth = 5, criterion = 'entropy', n_estimators = 200) 
xgb_2.fit(X_test, y_test)
# Out:
# C:\Users\Sandeep\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:160: UserWarning: [23:13:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0cec3277c4d9d0165-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "criterion" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, criterion='entropy', device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
# ...

# %%
pred_test2 = xgb2.predict(X_test)

print("Confusion matrix")
print(confusion_matrix(y_test, pred_test2))
print(" ")
print("Classification Report")
print(classification_report(y_test, pred_test2))
# Out:
# Confusion matrix
# [[116  27]
#  [ 26  62]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81       143
#            1       0.70      0.70      0.70        88
#
#     accuracy                           0.77       231
#    macro avg       0.76      0.76      0.76       231
# weighted avg       0.77      0.77      0.77       231

# %%
prob = xgb.predict_proba(X_test)
prob
# Out:
# array([[1.65772438e-03, 9.98342276e-01],
#        [9.00784492e-01, 9.92155150e-02],
#        [1.41202390e-01, 8.58797610e-01],
#        [9.93284702e-01, 6.71531633e-03],
#        [8.37398529e-01, 1.62601501e-01],
#        [1.07851446e-01, 8.92148554e-01],
#        [1.21771574e-01, 8.78228426e-01],
#        [1.06490254e-01, 8.93509746e-01],
#        [2.49221921e-01, 7.50778079e-01],
#        [2.97707319e-02, 9.70229268e-01],
#        [2.18017101e-02, 9.78198290e-01],
#        [8.14152956e-01, 1.85847029e-01],
#        [9.60495591e-01, 3.95044237e-02],
#        [4.45440531e-01, 5.54559469e-01],
#        [2.94697285e-03, 9.97053027e-01],
#        [9.98242259e-01, 1.75776589e-03],
#        [3.67950737e-01, 6.32049263e-01],
#        [9.99124944e-01, 8.75055324e-04],
#        [9.94379938e-01, 5.62007073e-03],
#        [7.95346498e-01, 2.04653487e-01],
#        [3.35255384e-01, 6.64744616e-01],
#        [9.97248471e-01, 2.75153015e-03],
#        [7.63360143e-01, 2.36639842e-01],
# ...

# %%
# Info must be noted in Excel spreadsheet to compare the data

# %% [markdown]
# ### ROC for Xgboost

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc

# %%
prob = prob[:,1]
prob
# Out:
# array([9.9834228e-01, 9.9215515e-02, 8.5879761e-01, 6.7153163e-03,
#        1.6260150e-01, 8.9214855e-01, 8.7822843e-01, 8.9350975e-01,
#        7.5077808e-01, 9.7022927e-01, 9.7819829e-01, 1.8584703e-01,
#        3.9504424e-02, 5.5455947e-01, 9.9705303e-01, 1.7577659e-03,
#        6.3204926e-01, 8.7505532e-04, 5.6200707e-03, 2.0465349e-01,
#        6.6474462e-01, 2.7515301e-03, 2.3663984e-01, 9.9549294e-01,
#        9.7163039e-01, 1.4790917e-02, 5.1167596e-04, 5.5241487e-03,
#        1.8164340e-01, 9.9573153e-01, 4.6462081e-03, 8.1348777e-01,
#        9.9796152e-01, 2.8958261e-02, 9.1749445e-02, 1.2560052e-02,
#        9.3385309e-01, 1.0366542e-02, 3.1230900e-02, 1.9778048e-01,
#        1.5207144e-04, 1.0494606e-03, 3.6098748e-02, 3.0997634e-01,
#        2.1760634e-03, 9.8923594e-01, 9.9164867e-01, 1.4684064e-03,
#        2.3480931e-02, 8.6331076e-04, 1.3530381e-03, 4.4599574e-04,
#        9.2403686e-01, 2.3265558e-03, 6.1546634e-03, 9.5731218e-04,
# ...

# %%
fpr, tpr, threshold = roc_curve(y_test, prob)

# %%
plt.plot(fpr, tpr)

# %%
roc_auc_score(y_test, prob)
# Out:
# 0.8310553083280356

# %%
# The closer the above value is to 1, the better the model
# Only used 4 binary classifier

# %% [markdown]
# ## 2) AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier()
ada.fit(X_train, y_train)
# Out:
# C:\Users\Sandeep\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostClassifier()

# %%
ada.predict_proba(X_train)
# Out:
# array([[0.50439016, 0.49560984],
#        [0.50121643, 0.49878357],
#        [0.49727396, 0.50272604],
#        ...,
#        [0.52372015, 0.47627985],
#        [0.51303869, 0.48696131],
#        [0.50366617, 0.49633383]])

# %% [markdown]
# ## 3) Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)
# Out:
# C:\Users\Sandeep\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingClassifier()

# %%
# Same code apparently :)
